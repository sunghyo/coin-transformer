# %%
import pyupbit
import pandas as pd
from datetime import datetime, timedelta
import json
import numpy as np

# %%
print(pyupbit.get_tickers(fiat="KRW"))
print(len(pyupbit.get_tickers(fiat="KRW")))
# Out:
# ['KRW-BTC', 'KRW-ETH', 'KRW-NEO', 'KRW-MTL', 'KRW-LTC', 'KRW-XRP', 'KRW-ETC', 'KRW-OMG', 'KRW-SNT', 'KRW-WAVES', 'KRW-XEM', 'KRW-QTUM', 'KRW-LSK', 'KRW-STEEM', 'KRW-XLM', 'KRW-ARDR', 'KRW-ARK', 'KRW-STORJ', 'KRW-GRS', 'KRW-REP', 'KRW-ADA', 'KRW-SBD', 'KRW-POWR', 'KRW-BTG', 'KRW-ICX', 'KRW-EOS', 'KRW-TRX', 'KRW-SC', 'KRW-ONT', 'KRW-ZIL', 'KRW-POLY', 'KRW-ZRX', 'KRW-LOOM', 'KRW-BCH', 'KRW-BAT', 'KRW-IOST', 'KRW-RFR', 'KRW-CVC', 'KRW-IQ', 'KRW-IOTA', 'KRW-MFT', 'KRW-ONG', 'KRW-GAS', 'KRW-UPP', 'KRW-ELF', 'KRW-KNC', 'KRW-BSV', 'KRW-THETA', 'KRW-QKC', 'KRW-BTT', 'KRW-MOC', 'KRW-ENJ', 'KRW-TFUEL', 'KRW-MANA', 'KRW-ANKR', 'KRW-AERGO', 'KRW-ATOM', 'KRW-TT', 'KRW-CRE', 'KRW-MBL', 'KRW-WAXP', 'KRW-HBAR', 'KRW-MED', 'KRW-MLK', 'KRW-STPT', 'KRW-ORBS', 'KRW-VET', 'KRW-CHZ', 'KRW-STMX', 'KRW-DKA', 'KRW-HIVE', 'KRW-KAVA', 'KRW-AHT', 'KRW-LINK', 'KRW-XTZ', 'KRW-BORA', 'KRW-JST', 'KRW-CRO', 'KRW-TON', 'KRW-SXP', 'KRW-HUNT', 'KRW-PLA', 'KRW-DOT', 'KRW-SRM', 'KRW-MVL', 'KRW-STRAX', 'KRW-AQT', 'KRW-GLM', 'KRW-SSX', 'KRW-META', 'KRW-FCT2', 'KRW-CBK', 'KRW-SAND', 'KRW-HUM', 'KRW-DOGE', 'KRW-STRK', 'KRW-PUNDIX', 'KRW-FLOW', 'KRW-DAWN', 'KRW-AXS', 'KRW-STX', 'KRW-XEC', 'KRW-SOL', 'KRW-MATIC', 'KRW-NU', 'KRW-AAVE', 'KRW-1INCH', 'KRW-ALGO']
# 108

# %%
from dataset import UpbitDataset, CoinDataset

# %%
data = UpbitDataset()

# %%
data_dict = data.read_json("KRW-BTC")
pd.DataFrame(data_dict)
# Out:
#                            open        high         low       close  \
# 2019-08-07 17:00:00  13769000.0  13866000.0  13674000.0  13806000.0
# 2019-08-07 18:00:00  13807000.0  13885000.0  13730000.0  13862000.0
# 2019-08-07 19:00:00  13862000.0  13940000.0  13856000.0  13857000.0
# 2019-08-07 20:00:00  13857000.0  13985000.0  13800000.0  13978000.0
# 2019-08-07 21:00:00  13979000.0  14066000.0  13914000.0  14016000.0
# ...                         ...         ...         ...         ...
# 2021-11-18 21:00:00  73145000.0  73890000.0  73087000.0  73221000.0
# 2021-11-18 22:00:00  73245000.0  73856000.0  73085000.0  73394000.0
# 2021-11-18 23:00:00  73397000.0  73505000.0  73127000.0  73235000.0
# 2021-11-19 00:00:00  73235000.0  73796000.0  72429000.0  72688000.0
# 2021-11-19 01:00:00  72688000.0  72949000.0  72126000.0  72307000.0
#
#                           volume         value
# 2019-08-07 17:00:00   667.478546  9.196916e+09
# 2019-08-07 18:00:00   402.228148  5.555882e+09
# 2019-08-07 19:00:00   333.103945  4.630656e+09
# 2019-08-07 20:00:00   457.431648  6.361318e+09
# 2019-08-07 21:00:00  1703.721334  2.385460e+10
# ...                          ...           ...
# 2021-11-18 21:00:00   365.052548  2.680910e+10
# 2021-11-18 22:00:00   364.677209  2.676239e+10
# 2021-11-18 23:00:00   314.672203  2.306133e+10
# 2021-11-19 00:00:00   675.983542  4.932813e+10
# 2021-11-19 01:00:00   310.290124  2.249583e+10
#
# [20000 rows x 6 columns]

# %%
btc_train_list, btc_val_list = data.get_ticker_data("KRW-BTC")
# Out:
# num_days 779

# %%
pd.DataFrame(btc_train_list[0])
# Out:
#           open        high        low       close      volume         value  \
# 0    9987000.0  10019000.0  9960000.0   9987000.0  205.508554  2.052681e+09
# 1    9987000.0  10036000.0  9971000.0  10002000.0  171.264041  1.713665e+09
# 2   10003000.0  10020000.0  9910000.0   9931000.0  246.508456  2.454258e+09
# 3    9930000.0   9944000.0  9876000.0   9930000.0  279.758310  2.772179e+09
# 4    9930000.0   9940000.0  9850000.0   9887000.0  264.686166  2.618091e+09
# 5    9899000.0   9899000.0  9814000.0   9828000.0  279.653479  2.754679e+09
# 6    9827000.0   9902000.0  9812000.0   9882000.0  201.293558  1.986991e+09
# 7    9881000.0   9935000.0  9874000.0   9902000.0  224.062455  2.221652e+09
# 8    9902000.0  10002000.0  9892000.0   9960000.0  209.824225  2.089662e+09
# 9    9960000.0   9988000.0  9937000.0   9948000.0  103.457499  1.030613e+09
# 10   9948000.0   9970000.0  9918000.0   9970000.0  146.880871  1.460046e+09
# 11   9969000.0  10002000.0  9941000.0   9987000.0  178.370399  1.778676e+09
# 12   9989000.0  10022000.0  9908000.0   9938000.0  185.889442  1.851933e+09
# 13   9938000.0   9990000.0  9895000.0   9920000.0  165.803020  1.647722e+09
# 14   9923000.0   9965000.0  9907000.0   9951000.0  101.444256  1.007819e+09
# 15   9950000.0   9957000.0  9920000.0   9930000.0   52.650543  5.230387e+08
# 16   9945000.0   9992000.0  9915000.0   9915000.0  130.398957  1.297824e+09
# 17   9915000.0   9940000.0  9874000.0   9940000.0   73.242594  7.256464e+08
# 18   9940000.0   9974000.0  9916000.0   9931000.0   69.578961  6.918762e+08
# 19   9931000.0   9974000.0  9914000.0   9960000.0   28.545429  2.834628e+08
# 20   9960000.0   9970000.0  9925000.0   9938000.0   17.662041  1.756900e+08
# 21   9929000.0   9995000.0  9928000.0   9971000.0   46.211281  4.600094e+08
# 22   9971000.0   9994000.0  9940000.0   9977000.0   32.487025  3.239822e+08
# 23   9976000.0  10092000.0  9975000.0  10077000.0  279.917601  2.812067e+09
#
#                   date  missing    z_open    z_high     z_low   z_close  \
# 0  2019-10-02 09:00:00    False  0.000000  0.003204 -0.002704  0.000000
# 1  2019-10-02 10:00:00    False -0.001500  0.003399 -0.003099  0.001502
# 2  2019-10-02 11:00:00    False  0.007250  0.008962 -0.002115 -0.007099
# 3  2019-10-02 12:00:00    False  0.000000  0.001410 -0.005438 -0.000101
# 4  2019-10-02 13:00:00    False  0.004349  0.005361 -0.003742 -0.004330
# 5  2019-10-02 14:00:00    False  0.007224  0.007224 -0.001425 -0.005967
# 6  2019-10-02 15:00:00    False -0.005566  0.002024 -0.007084  0.005495
# 7  2019-10-02 16:00:00    False -0.002121  0.003333 -0.002828  0.002024
# 8  2019-10-02 17:00:00    False -0.005823  0.004217 -0.006827  0.005857
# 9  2019-10-02 18:00:00    False  0.001206  0.004021 -0.001106 -0.001205
# 10 2019-10-02 19:00:00    False -0.002207  0.000000 -0.005216  0.002211
# 11 2019-10-02 20:00:00    False -0.001802  0.001502 -0.004606  0.001705
# 12 2019-10-02 21:00:00    False  0.005132  0.008452 -0.003019 -0.004906
# 13 2019-10-02 22:00:00    False  0.001815  0.007056 -0.002520 -0.001811
# 14 2019-10-02 23:00:00    False -0.002814  0.001407 -0.004422  0.003125
# 15 2019-10-03 00:00:00    False  0.002014  0.002719 -0.001007 -0.002110
# 16 2019-10-03 01:00:00    False  0.003026  0.007766  0.000000 -0.001511
# 17 2019-10-03 02:00:00    False -0.002515  0.000000 -0.006640  0.002521
# 18 2019-10-03 03:00:00    False  0.000906  0.004330 -0.001510 -0.000905
# 19 2019-10-03 04:00:00    False -0.002912  0.001406 -0.004618  0.002920
# 20 2019-10-03 05:00:00    False  0.002214  0.003220 -0.001308 -0.002209
# 21 2019-10-03 06:00:00    False -0.004212  0.002407 -0.004313  0.003321
# 22 2019-10-03 07:00:00    False -0.000601  0.001704 -0.003709  0.000602
# 23 2019-10-03 08:00:00    False -0.010023  0.001489 -0.010122  0.010023
#
#     z_volume  label
# 0   0.180983      0
# 1  -0.166633      0
# 2   0.439347      0
# 3   0.134883      0
# 4  -0.053876      0
# 5   0.056547      0
# 6  -0.280204      0
# 7   0.113113      0
# 8  -0.063546      0
# 9  -0.506933      0
# 10  0.419722      0
# 11  0.214388      0
# 12  0.042154      0
# 13 -0.108056      0
# 14 -0.388164      0
# 15 -0.480990      0
# 16  1.476688      0
# 17 -0.438319      0
# 18 -0.050021      0
# 19 -0.589741      0
# 20 -0.381266      0
# 21  1.616418      0
# 22 -0.296989      0
# 23  7.616289      0

# %%
upbit_data = UpbitDataset()
train_list, val_list = upbit_data.get_data()

train_dataset = CoinDataset(train_list)
val_dataset = CoinDataset(val_list)
# Out:
# KRW-BTC train: 684 val: 76
# KRW-ETH train: 684 val: 76
# KRW-NEO train: 684 val: 76
# KRW-MTL train: 684 val: 76
# KRW-LTC train: 684 val: 76
# KRW-XRP train: 684 val: 76
# KRW-ETC train: 684 val: 76
# KRW-OMG train: 684 val: 76
# KRW-SNT train: 684 val: 76
# KRW-WAVES train: 684 val: 76
# KRW-XEM train: 684 val: 76
# KRW-QTUM train: 684 val: 76
# KRW-LSK train: 684 val: 76
# KRW-STEEM train: 684 val: 76
# KRW-XLM train: 684 val: 76
# KRW-ARDR train: 684 val: 76
# KRW-ARK train: 684 val: 76
# KRW-STORJ train: 684 val: 76
# KRW-GRS train: 684 val: 76
# KRW-REP train: 684 val: 76
# KRW-ADA train: 684 val: 76
# KRW-SBD train: 684 val: 76
# KRW-POWR train: 684 val: 76
# KRW-BTG train: 684 val: 76
# KRW-ICX train: 684 val: 76
# KRW-EOS train: 684 val: 76
# KRW-TRX train: 684 val: 76
# KRW-SC train: 684 val: 76
# KRW-ONT train: 684 val: 76
# KRW-ZIL train: 684 val: 76
# KRW-POLY train: 684 val: 76
# KRW-ZRX train: 684 val: 76
# KRW-LOOM train: 684 val: 76
# KRW-BCH train: 684 val: 76
# KRW-BAT train: 684 val: 76
# KRW-IOST train: 684 val: 76
# KRW-RFR train: 684 val: 76
# KRW-CVC train: 684 val: 76
# KRW-IQ train: 684 val: 76
# KRW-IOTA train: 684 val: 76
# KRW-MFT train: 684 val: 76
# KRW-ONG train: 684 val: 76
# KRW-GAS train: 684 val: 76
# KRW-UPP train: 684 val: 76
# KRW-ELF train: 684 val: 76
# KRW-KNC train: 684 val: 76
# KRW-BSV train: 684 val: 76
# KRW-THETA train: 684 val: 76
# KRW-QKC train: 684 val: 76
# KRW-BTT train: 684 val: 76
# KRW-MOC train: 684 val: 76
# KRW-ENJ train: 684 val: 76
# KRW-TFUEL train: 684 val: 76
# KRW-MANA train: 684 val: 76
# KRW-ANKR train: 684 val: 76
# KRW-AERGO train: 684 val: 76
# KRW-ATOM train: 684 val: 76
# KRW-TT train: 684 val: 76
# KRW-CRE train: 684 val: 76
# KRW-MBL train: 684 val: 76
# KRW-WAXP train: 684 val: 76
# KRW-HBAR train: 684 val: 76
# KRW-MED train: 684 val: 76
# Skip KRW-MLK No record
# Skip KRW-STPT No record
# Skip KRW-ORBS No record
# Skip KRW-VET No record
# Skip KRW-CHZ No record
# KRW-STMX train: 684 val: 76
# Skip KRW-DKA No record
# Skip KRW-HIVE No record
# Skip KRW-KAVA No record
# Skip KRW-AHT No record
# Skip KRW-LINK No record
# Skip KRW-XTZ No record
# Skip KRW-BORA No record
# Skip KRW-JST No record
# Skip KRW-CRO No record
# Skip KRW-TON No record
# Skip KRW-SXP No record
# Skip KRW-HUNT No record
# Skip KRW-PLA No record
# Skip KRW-DOT No record
# Skip KRW-SRM No record
# Skip KRW-MVL No record
# KRW-STRAX train: 684 val: 76
# Skip KRW-AQT No record
# KRW-GLM train: 684 val: 76
# Skip KRW-SSX No record
# Skip KRW-META No record
# Skip KRW-FCT2 No record
# Skip KRW-CBK No record
# Skip KRW-SAND No record
# Skip KRW-HUM No record
# Skip KRW-DOGE No record
# Skip KRW-STRK No record
# KRW-PUNDIX train: 684 val: 76
# Skip KRW-FLOW No record
# Skip KRW-DAWN No record
# Skip KRW-AXS No record
# Skip KRW-STX No record
# Skip KRW-XEC No record
# Skip KRW-SOL No record
# Skip KRW-MATIC No record
# Skip KRW-NU No record
# Skip KRW-AAVE No record
# Skip KRW-1INCH No record
# Skip KRW-ALGO No record
# Num train 45828
# Num val 5092
